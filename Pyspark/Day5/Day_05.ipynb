# %%
df=spark.read.format("csv").option('header',True).option('inferSchema',True).load("/Volumes/workspace/default/databricks/Big Sales.csv")

# %% [markdown]
# ### Date Functions

# %%
#Current date
from pyspark.sql.functions import *
df_currdate = df.withColumn("Curr_date",current_date())
df_currdate.display()

# %%
#date_add()
df_weekafetr = df_currdate.withColumn("WeekAfter",date_add(col("Curr_date"),7))
df_weekafetr.display()

# %%
#date_sub()
df_weekbefore=df_weekafetr.withColumn("WeekBefore",date_sub(col("Curr_date"),7))
df_weekbefore.display()

# %%
#DateDiff
df_days = df_weekbefore.withColumn("DateDiff",date_diff(col("weekafter"),col("weekbefore")))
df_days.display()

# %%
#date_format
df_days.withColumn("Datechange",date_format('Curr_date','dd-MM-yyyy')).display()
